# %% [markdown]
# # Machine Learning Basics
# In this module, you'll be analysing a dataset. You will be using the Cinema Data for the tasks in this module. <br> <br>
# **Pipeline:**
# * Acquiring the data - done
# * Handling files and formats - done
# * Data Analysis
# * Prediction
# * Analysing results

# %% [markdown]
# ## Task 1 - Plotting
# * Plot the values of occupancy percentage versus number of weeks since release, for all movies in the dataset.
# * Plot the number of other releases in the week versus occupancy percentage and weeks until the end of lifetime, for all movies.
# * Plot the number of shows in the week versus occupancy percentage and weeks until the end of lifetime, for all movies.

# %%
import pandas as pd
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
import json
df=pd.DataFrame()
with open(r"/Users/msml/Vamsi/SF/MLBasics-master/Data/CinemaData.json")as f:
    data=json.load(f)
    df=pd.DataFrame(data)
    end_week=df['ShowsInWeek']
    occper=df['OccPer']
    weeks=df['WeeksSinceRelease']
    #plt.plot(occper,weeks)
    #plt.xlabel('Occupancy percent')
    #plt.ylabel('weeks since release ')
    #plt.zlabel('end_week')'''
    plt.figure(figsize=(20,9))

    plt.subplot(131)
    plt.bar(occper,weeks)
    plt.subplot(132)
    plt.scatter(occper,weeks)
    plt.subplot(133)
    plt.plot(occper,weeks)
    plt.suptitle('Categorical Plotting')
    plt.show()

# %%
import pandas as pd
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
import json
df=pd.DataFrame()
with open(r"/Users/msml/Vamsi/SF/MLBasics-master/Data/CinemaData.json")as f:
    data=json.load(f)
    df=pd.DataFrame(data)
    occper=df['OccPer']
    other_rel=df['OtherReleasesInWeek']
    end_week=df['ShowsInWeek']
    ''''plt.plot(other_rel,occper)
    plt.ylabel('Occupancy percent')
    plt.xlabel('number of other releases')'''
    #plt.zlabel('weeks until the end of lifetime')
    #fig = plt.figure()
    #ax = plt.axes(projection='3d')
    #ax.contour3D(other_rel,occper,end_week, 50, cmap='binary')
    #ax.set_xlabel('x')
    #ax.set_ylabel('y')
    #ax.set_zlabel('z');
    plt.figure(figsize=(20,9))

    plt.subplot(131)
    plt.bar(other_rel,occper)
    plt.subplot(132)
    plt.scatter(other_rel,occper)
    plt.subplot(133)
    plt.plot(other_rel,occper)
    plt.suptitle('Categorical Plotting')
    plt.show()

# %%
import pandas as pd
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
import json
df=pd.DataFrame()
with open(r"/Users/msml/Vamsi/SF/MLBasics-master/Data/CinemaData.json")as f:
    data=json.load(f)
    df=pd.DataFrame(data)
    occper=df['OccPer']
    shows=df['ShowsInWeek']
    ''''plt.plot(occper,shows)
    plt.xlabel('Occupancy percent')
    plt.ylabel('shows in week ')'''
    #plt.zlabel('end_week')
    plt.figure(figsize=(20,9))

    plt.subplot(131)
    plt.bar(occper,shows)
    plt.subplot(132)
    plt.scatter(occper,shows)
    plt.subplot(133)
    plt.plot(occper,shows)
    plt.suptitle('Categorical Plotting')
    plt.show()

# %% [markdown]
# ## Task 2 - Reasoning
# Now that you have the plots, identify the correlation between the various parameters analysed. Justify the correlations, your observations, and your hypotheses for the same with appropriate reasoning.
